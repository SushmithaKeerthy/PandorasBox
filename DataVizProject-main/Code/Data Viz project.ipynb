# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('share-deaths-aids.csv')

# %%
df.isnull().sum()
# Out:
# Entity                                                       0
# Code                                                       690
# Year                                                         0
# Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Percent)      0
# dtype: int64

# %%
df.rename(columns = {'Entity':'Location', 'Code':'Country Code'}, inplace = True)

# %%
df.shape
# Out:
# (6840, 4)

# %%
df1 = df.dropna()

# %%
df1.isnull().sum()
# Out:
# Location                                                   0
# Country Code                                               0
# Year                                                       0
# Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Percent)    0
# dtype: int64

# %%
df1.shape
# Out:
# (6150, 4)

# %%
df1.to_csv('HIV_deaths_precessed_data.csv')

# %%
df2= pd.read_csv('new malaria cases.csv')

# %%
df2.isnull().sum()
# Out:
# Entity                                                   0
# Code                                                   210
# Year                                                     0
# Incidence of malaria (per 1,000 population at risk)      0
# dtype: int64

# %%
df2.shape
# Out:
# (2442, 4)

# %%
df2 = df2.dropna()

# %%
df2.shape
# Out:
# (2232, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6840 entries, 0 to 6839
# Data columns (total 4 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Entity                                                   6840 non-null   object
#  1   Code                                                     6150 non-null   object
#  2   Year                                                     6840 non-null   int64
#  3   Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Percent)  6840 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 213.9+ KB

# %%
df2.rename(columns = {'Entity':'Location', 'Code':'Country Code'}, inplace = True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2232 entries, 0 to 2441
# Data columns (total 4 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Location                                             2232 non-null   object
#  1   Country Code                                         2232 non-null   object
#  2   Year                                                 2232 non-null   int64
#  3   Incidence of malaria (per 1,000 population at risk)  2232 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 87.2+ KB

# %%
df2.to_csv('Maleria_deaths_precessed_data.csv')

# %% [markdown]
# ## Adding population column

# %%
data_malaria = pd.read_csv('DataVizProject/Dataset/Maleria_deaths_processed_data.csv')

# %%
data_malaria
# Out:
#       Unnamed: 0     Location Country Code  Year  \
# 0              0  Afghanistan          AFG  2000
# 1              1  Afghanistan          AFG  2001
# 2              2  Afghanistan          AFG  2002
# 3              3  Afghanistan          AFG  2003
# 4              4  Afghanistan          AFG  2004
# ...          ...          ...          ...   ...
# 2227        2437     Zimbabwe          ZWE  2016
# 2228        2438     Zimbabwe          ZWE  2017
# 2229        2439     Zimbabwe          ZWE  2018
# 2230        2440     Zimbabwe          ZWE  2019
# 2231        2441     Zimbabwe          ZWE  2020
#
#       Incidence of malaria (per 1,000 population at risk)
# 0                                             81.969559
# 1                                             78.832069
# 2                                             79.385788
# 3                                             68.091560
# 4                                             37.616467
# ...

# %%
data_malaria['pop'] = ''

# %%
population = pd.read_csv('Country_population.csv')

# %%
countries = population.country
population.drop(columns=['country'], inplace=True)
population = population.astype(str).astype(int)
population['country'] = countries

# %%
population.to_csv("pop_cleaned.csv")

# %%
data_malaria.drop(columns=['Unnamed: 0'], inplace=True)

# %%
data_malaria
# Out:
#          Location Country Code  Year  \
# 0     Afghanistan          AFG  2000
# 1     Afghanistan          AFG  2001
# 2     Afghanistan          AFG  2002
# 3     Afghanistan          AFG  2003
# 4     Afghanistan          AFG  2004
# ...           ...          ...   ...
# 2227     Zimbabwe          ZWE  2016
# 2228     Zimbabwe          ZWE  2017
# 2229     Zimbabwe          ZWE  2018
# 2230     Zimbabwe          ZWE  2019
# 2231     Zimbabwe          ZWE  2020
#
#       Incidence of malaria (per 1,000 population at risk) pop
# 0                                             81.969559
# 1                                             78.832069
# 2                                             79.385788
# 3                                             68.091560
# 4                                             37.616467
# ...                                                 ...    ..
# 2227                                          68.375832
# ...

# %%
population.columns
# Out:
# Index(['Country ', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
population.replace(',','', regex=True, inplace=True)

# %%
population['country'] = population['Country\xa0']

# %%
population.drop(columns=['Country\xa0'], inplace=True)

# %%
population['1990'][0][2]
# Out:
# '6'

# %%
convert_dict = {'1990': int,
                '1990': int,
                '1991': int,
                '1992': int,
                '1993': int,
                '1994': int,
                '1995': int,
                '1996': int,
                '1997': int,
                '1998': int,
                '1999': int,
                '2000': int,
                '2001': int,
                '2002': int,
                '2003': int,
                '2004': int,
                '2005': int,
                '2006': int,
                '2007': int,
                '2008': int,
                '2009': int,
                '2010': int,
                '2011': int,
                '2012': int,
                '2013': int,
                '2014': int,
                '2015': int,
                '2016': int,
                '2017': int,
                '2018': int,
                '2019': int,
                '2020': int}  

df = population.astype(convert_dict)

# %%
population[population['country'] == 'Afghanistan']['1990'].astype('int')[0]
# Out:
# 10694796

# %%
data_malaria.columns
# Out:
# Index(['Location', 'Country Code', 'Year',
#        'Incidence of malaria (per 1,000 population at risk)', 'pop'],
#       dtype='object')

# %%
data_malaria.Year = data_malaria.Year.astype(str)

# %%
# Out:
# country=  Afghanistan
# Year =  2000
# 0    19542982
# Name: 2000, dtype: int64
# country=  Afghanistan
# Year =  2001
# 0    19542982
# Name: 2001, dtype: int64
# country=  Afghanistan
# Year =  2002
# 0    19542982
# Name: 2002, dtype: int64
# country=  Afghanistan
# Year =  2003
# 0    19542982
# Name: 2003, dtype: int64
# country=  Afghanistan
# Year =  2004
# 0    19542982
# Name: 2004, dtype: int64
# country=  Afghanistan
# Year =  2005
# 0    19542982
# Name: 2005, dtype: int64
# country=  Afghanistan
# Year =  2006
# 0    19542982
# Name: 2006, dtype: int64
# country=  Afghanistan
# Year =  2007
# 0    19542982
# Name: 2007, dtype: int64
# country=  Afghanistan
# Year =  2008
# 0    19542982
# Name: 2008, dtype: int64
# country=  Afghanistan
# Year =  2009
# 0    19542982
# Name: 2009, dtype: int64
# country=  Afghanistan
# Year =  2010
# 0    28189672
# Name: 2010, dtype: int64
# country=  Afghanistan
# Year =  2011
# 0    28189672
# Name: 2011, dtype: int64
# ...

# %%
data_malaria
# Out:
#          Location Country Code  Year  \
# 0     Afghanistan          AFG  2000
# 1     Afghanistan          AFG  2001
# 2     Afghanistan          AFG  2002
# 3     Afghanistan          AFG  2003
# 4     Afghanistan          AFG  2004
# ...           ...          ...   ...
# 2227     Zimbabwe          ZWE  2016
# 2228     Zimbabwe          ZWE  2017
# 2229     Zimbabwe          ZWE  2018
# 2230     Zimbabwe          ZWE  2019
# 2231     Zimbabwe          ZWE  2020
#
#       Incidence of malaria (per 1,000 population at risk) pop
# 0                                             81.969559
# 1                                             78.832069
# 2                                             79.385788
# 3                                             68.091560
# 4                                             37.616467
# ...                                                 ...    ..
# 2227                                          68.375832
# ...

# %%
pop
# Out:
# 0      19542982
# 1       3182021
# 2      30774621
# 3         66097
# 4      16394062
#          ...
# 200    79001142
# 201      270375
# 202    18628700
# 203     9891136
# 204    11834676
# Name: 2000, Length: 205, dtype: object

# %%
population = pd.read_csv('pop_cleaned.csv')

# %%
population.drop(columns=['Unnamed: 0'], inplace = True)

# %%
population
# Out:
#          1990      1991      1992      1993      1994      1995      1996  \
# 0    10694796  10694796  10694796  10694796  10694796  10694796  10694796
# 1     3295066   3295066   3295066   3295066   3295066   3295066   3295066
# 2    25518074  25518074  25518074  25518074  25518074  25518074  25518074
# 3       53569     53569     53569     53569     53569     53569     53569
# 4    11828638  11828638  11828638  11828638  11828638  11828638  11828638
# ..        ...       ...       ...       ...       ...       ...       ...
# 200  66912613  66912613  66912613  66912613  66912613  66912613  66912613
# 201    178529    178529    178529    178529    178529    178529    178529
# 202  13375121  13375121  13375121  13375121  13375121  13375121  13375121
# 203   7686401   7686401   7686401   7686401   7686401   7686401   7686401
# 204  10113893  10113893  10113893  10113893  10113893  10113893  10113893
#
#          1997      1998      1999  ...      2012      2013      2014  \
# ...

# %%
indexAge = data_malaria[ (data_malaria['Location'] == 'Congo')].index
data_malaria.drop(indexAge , inplace=True)

# %%
indexAge = data_malaria[ (data_malaria['Location'] == 'World')].index
data_malaria.drop(indexAge , inplace=True)

# %%
pop_val = []
for index, row in data_malaria.iterrows():

    y = str(row['Year'])
#     print("country= ", row['Location'])
#     print("Year = ", y)
#     print(population[population['country'] == row['Location']][str(y)].astype('int'))
#     print(population[population['country'] == row['Location']][y].values)   
#     print(population[population['country'] == row['Location']][y].values[0])
    pop_val.append(population[population['country'] == row['Location']][y].values[0])

# %%
data_malaria['pop'] = pop_val

# %%
data_malaria.to_csv('malaria_clean.csv')

# %%
data_malaria['cases'] = data_malaria['Incidence of malaria (per 1,000 population at risk)'] * (data_malaria['pop']/1000)

# %%
population[population['country'] == 'Afghanistan']['2000'][0]
# Out:
# 19542982

# %%
data_malaria['cases'] = data_malaria['cases'].astype('int')
data_malaria.to_csv('malaria_clean.csv')

# %%
hiv = pd.read_csv('DataVizProject/Dataset/HIV_deaths_processed_data.csv')

# %%
hiv
# Out:
#       Unnamed: 0     Location Country Code  Year  \
# 0              0  Afghanistan          AFG  1990
# 1              1  Afghanistan          AFG  1991
# 2              2  Afghanistan          AFG  1992
# 3              3  Afghanistan          AFG  1993
# 4              4  Afghanistan          AFG  1994
# ...          ...          ...          ...   ...
# 6145        6835     Zimbabwe          ZWE  2015
# 6146        6836     Zimbabwe          ZWE  2016
# 6147        6837     Zimbabwe          ZWE  2017
# 6148        6838     Zimbabwe          ZWE  2018
# 6149        6839     Zimbabwe          ZWE  2019
#
#       Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Percent)
# 0                                                  0.02
# 1                                                  0.02
# 2                                                  0.02
# 3                                                  0.02
# 4                                                  0.03
# ...

# %%
data_malaria
# Out:
#          Location Country Code  Year  \
# 0     Afghanistan          AFG  2000
# 1     Afghanistan          AFG  2001
# 2     Afghanistan          AFG  2002
# 3     Afghanistan          AFG  2003
# 4     Afghanistan          AFG  2004
# ...           ...          ...   ...
# 2227     Zimbabwe          ZWE  2016
# 2228     Zimbabwe          ZWE  2017
# 2229     Zimbabwe          ZWE  2018
# 2230     Zimbabwe          ZWE  2019
# 2231     Zimbabwe          ZWE  2020
#
#       Incidence of malaria (per 1,000 population at risk)       pop    cases
# 0                                             81.969559    19542982  1601929
# 1                                             78.832069    19542982  1540613
# 2                                             79.385788    19542982  1551435
# 3                                             68.091560    19542982  1330712
# 4                                             37.616467    19542982   735137
# ...

# %%
hiv
# Out:
#          Location Country Code  Year  \
# 0     Afghanistan          AFG  1990
# 1     Afghanistan          AFG  1991
# 2     Afghanistan          AFG  1992
# 3     Afghanistan          AFG  1993
# 4     Afghanistan          AFG  1994
# ...           ...          ...   ...
# 6145     Zimbabwe          ZWE  2015
# 6146     Zimbabwe          ZWE  2016
# 6147     Zimbabwe          ZWE  2017
# 6148     Zimbabwe          ZWE  2018
# 6149     Zimbabwe          ZWE  2019
#
#       Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Percent)
# 0                                                  0.02
# 1                                                  0.02
# 2                                                  0.02
# 3                                                  0.02
# 4                                                  0.03
# ...                                                 ...
# 6145                                              21.96
# ...

# %%
population = pd.read_csv('pop_cleaned.csv')

# %%
pop_val = []
for index, row in hiv.iterrows():

    y = str(row['Year'])
    print("country= ", row['Location'])
    print("Year = ", y)
#     print(population[population['country'] == row['Location']][str(y)].astype('int'))
#     print(population[population['country'] == row['Location']][y].values)   
#     print(population[population['country'] == row['Location']][y].values[0])
    pop_val.append(population[population['country'] == row['Location']][y].values[0])
# Out:
# country=  Afghanistan
# Year =  1990
# country=  Afghanistan
# Year =  1991
# country=  Afghanistan
# Year =  1992
# country=  Afghanistan
# Year =  1993
# country=  Afghanistan
# Year =  1994
# country=  Afghanistan
# Year =  1995
# country=  Afghanistan
# Year =  1996
# country=  Afghanistan
# Year =  1997
# country=  Afghanistan
# Year =  1998
# country=  Afghanistan
# Year =  1999
# country=  Afghanistan
# Year =  2000
# country=  Afghanistan
# Year =  2001
# country=  Afghanistan
# Year =  2002
# country=  Afghanistan
# Year =  2003
# country=  Afghanistan
# Year =  2004
# country=  Afghanistan
# Year =  2005
# country=  Afghanistan
# Year =  2006
# country=  Afghanistan
# Year =  2007
# country=  Afghanistan
# Year =  2008
# country=  Afghanistan
# Year =  2009
# country=  Afghanistan
# Year =  2010
# country=  Afghanistan
# Year =  2011
# country=  Afghanistan
# Year =  2012
# country=  Afghanistan
# Year =  2013
# country=  Afghanistan
# Year =  2014
# country=  Afghanistan
# ...

# %%
indexAge = hiv[ (hiv['Location'] == 'World')].index
hiv.drop(indexAge , inplace=True)

# %%
hiv['pop'] = pop_val

# %%
hiv['death'] = hiv['Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Percent)'] * (hiv['pop']/100)
hiv['death'] = hiv['death'].astype('int')
hiv.to_csv('hiv_cleaned.csv')
hiv
# Out:
#          Location Country Code  Year  \
# 0     Afghanistan          AFG  1990
# 1     Afghanistan          AFG  1991
# 2     Afghanistan          AFG  1992
# 3     Afghanistan          AFG  1993
# 4     Afghanistan          AFG  1994
# ...           ...          ...   ...
# 6145     Zimbabwe          ZWE  2015
# 6146     Zimbabwe          ZWE  2016
# 6147     Zimbabwe          ZWE  2017
# 6148     Zimbabwe          ZWE  2018
# 6149     Zimbabwe          ZWE  2019
#
#       Deaths - HIV/AIDS - Sex: Both - Age: All Ages (Percent)       pop  \
# 0                                                  0.02        10694796
# 1                                                  0.02        10694796
# 2                                                  0.02        10694796
# 3                                                  0.02        10694796
# 4                                                  0.03        10694796
# ...                                                 ...             ...
# ...

# %%
hiv.to_csv('hiv_cleaned.csv')

# %%
covid = pd.read_excel('Covid Clean.xlsx')

# %%
covid
# Out:
#      Month-Year     location   Death
# 0    2020-02-01  Afghanistan       0
# 1    2020-03-01  Afghanistan      21
# 2    2020-04-01  Afghanistan     812
# 3    2020-05-01  Afghanistan    4924
# 4    2020-06-01  Afghanistan   14982
# ...         ...          ...     ...
# 7970 2022-07-01     Zimbabwe  172562
# 7971 2022-08-01     Zimbabwe  173223
# 7972 2022-09-01     Zimbabwe  167925
# 7973 2022-10-01     Zimbabwe  173752
# 7974 2022-11-01     Zimbabwe   44848
#
# [7975 rows x 3 columns]

# %%
data_malaria
# Out:
#          Location Country Code  Year  \
# 0     Afghanistan          AFG  2000
# 1     Afghanistan          AFG  2001
# 2     Afghanistan          AFG  2002
# 3     Afghanistan          AFG  2003
# 4     Afghanistan          AFG  2004
# ...           ...          ...   ...
# 2227     Zimbabwe          ZWE  2016
# 2228     Zimbabwe          ZWE  2017
# 2229     Zimbabwe          ZWE  2018
# 2230     Zimbabwe          ZWE  2019
# 2231     Zimbabwe          ZWE  2020
#
#       Incidence of malaria (per 1,000 population at risk)       pop    cases
# 0                                             81.969559    19542982  1601929
# 1                                             78.832069    19542982  1540613
# 2                                             79.385788    19542982  1551435
# 3                                             68.091560    19542982  1330712
# 4                                             37.616467    19542982   735137
# ...

# %%
covid_unclean = pd.read_csv('owid-covid-data.csv')

# %%
covid_unclean[covid_unclean['location']=='Africa']
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 989   OWID_AFR       NaN   Africa  2020-02-13          NaN        0.0
# 990   OWID_AFR       NaN   Africa  2020-02-14          1.0        1.0
# 991   OWID_AFR       NaN   Africa  2020-02-15          1.0        0.0
# 992   OWID_AFR       NaN   Africa  2020-02-16          1.0        0.0
# 993   OWID_AFR       NaN   Africa  2020-02-17          1.0        0.0
# ...        ...       ...      ...         ...          ...        ...
# 1984  OWID_AFR       NaN   Africa  2022-11-04   12389249.0     1096.0
# 1985  OWID_AFR       NaN   Africa  2022-11-05   12389566.0      317.0
# 1986  OWID_AFR       NaN   Africa  2022-11-06   12389958.0      392.0
# 1987  OWID_AFR       NaN   Africa  2022-11-07   12392937.0     3005.0
# 1988  OWID_AFR       NaN   Africa  2022-11-08   12393858.0      921.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
cov_iso = []
for index, row in covid.iterrows():
#     print(population[population['country'] == row['Location']][str(y)].astype('int'))
#     print(population[population['country'] == row['Location']][y].values)   
    print((set(covid_unclean[covid_unclean['location'] == row['location']]['iso_code'])))

# %%
data_malaria[data_malaria['Location'] == 'Afghanistan']['Country Code'][0]
# Out:
# 'AFG'

# %%
indexAge = covid[ (covid['location'] == 'Antartica America')].index
covid.drop(indexAge , inplace=True)

# %%
iso_code = {}
for index, row in covid_unclean.iterrows():
    if row['location'] not in iso_code:
        iso_code[row['location']] = row['iso_code']

# %%
iso_code
# Out:
# {'Afghanistan': 'AFG',
#  'Africa': 'OWID_AFR',
#  'Albania': 'ALB',
#  'Algeria': 'DZA',
#  'Andorra': 'AND',
#  'Angola': 'AGO',
#  'Anguilla': 'AIA',
#  'Antigua and Barbuda': 'ATG',
#  'Argentina': 'ARG',
#  'Armenia': 'ARM',
#  'Aruba': 'ABW',
#  'Asia': 'OWID_ASI',
#  'Australia': 'AUS',
#  'Austria': 'AUT',
#  'Azerbaijan': 'AZE',
#  'Bahamas': 'BHS',
#  'Bahrain': 'BHR',
#  'Bangladesh': 'BGD',
#  'Barbados': 'BRB',
#  'Belarus': 'BLR',
#  'Belgium': 'BEL',
#  'Belize': 'BLZ',
#  'Benin': 'BEN',
#  'Bermuda': 'BMU',
#  'Bhutan': 'BTN',
#  'Bolivia': 'BOL',
#  'Bonaire Sint Eustatius and Saba': 'BES',
#  'Bosnia and Herzegovina': 'BIH',
#  'Botswana': 'BWA',
#  'Brazil': 'BRA',
#  'British Virgin Islands': 'VGB',
#  'Brunei': 'BRN',
#  'Bulgaria': 'BGR',
#  'Burkina Faso': 'BFA',
#  'Burundi': 'BDI',
#  'Cambodia': 'KHM',
#  'Cameroon': 'CMR',
#  'Canada': 'CAN',
#  'Cape Verde': 'CPV',
#  'Cayman Islands': 'CYM',
#  'Central African Republic': 'CAF',
#  'Chad': 'TCD',
# ...

# %%
l1 = set(l1)
l2 = set(l2)row[]

# %%
for i in l2:
    if i not in l1:
        print(i)
# Out:
# North America
# Asia
# Europe
# South America
# Africa

# %%
iso = []
for index,row in covid.iterrows():
    iso.append(iso_code[row['location']])

# %%
len(iso)
# Out:
# 7975

# %%
covid['iso_code'] = iso

# %%
covid.to_csv('covid_clean.csv')

# %%
covid
# Out:
#      Month-Year     location   Death iso_code
# 0    2020-02-01  Afghanistan       0      AFG
# 1    2020-03-01  Afghanistan      21      AFG
# 2    2020-04-01  Afghanistan     812      AFG
# 3    2020-05-01  Afghanistan    4924      AFG
# 4    2020-06-01  Afghanistan   14982      AFG
# ...         ...          ...     ...      ...
# 7970 2022-07-01     Zimbabwe  172562      ZWE
# 7971 2022-08-01     Zimbabwe  173223      ZWE
# 7972 2022-09-01     Zimbabwe  167925      ZWE
# 7973 2022-10-01     Zimbabwe  173752      ZWE
# 7974 2022-11-01     Zimbabwe   44848      ZWE
#
# [7975 rows x 4 columns]

# %%
data_malaria
# Out:
#          Location Country Code  Year  \
# 0     Afghanistan          AFG  2000
# 1     Afghanistan          AFG  2001
# 2     Afghanistan          AFG  2002
# 3     Afghanistan          AFG  2003
# 4     Afghanistan          AFG  2004
# ...           ...          ...   ...
# 2227     Zimbabwe          ZWE  2016
# 2228     Zimbabwe          ZWE  2017
# 2229     Zimbabwe          ZWE  2018
# 2230     Zimbabwe          ZWE  2019
# 2231     Zimbabwe          ZWE  2020
#
#       Incidence of malaria (per 1,000 population at risk)       pop    cases
# 0                                             81.969559    19542982  1601929
# 1                                             78.832069    19542982  1540613
# 2                                             79.385788    19542982  1551435
# 3                                             68.091560    19542982  1330712
# 4                                             37.616467    19542982   735137
# ...

# %%
hiv.to_csv('hiv_cleaned.xlsx')

# %%
data_malaria.to_csv('malaria_clean.xlsx')

# %%
hiv.death.nsmallest(500)
# Out:
# 240       0
# 241       0
# 242       0
# 243       0
# 244       0
#        ...
# 2420    190
# 2421    190
# 2422    190
# 2423    190
# 3309    193
# Name: death, Length: 500, dtype: int64
